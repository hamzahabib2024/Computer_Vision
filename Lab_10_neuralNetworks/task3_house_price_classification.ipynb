# %% [markdown]
# # Task 3 — House Price Category Prediction (Low / High)
# Predict whether a house price is **Low** or **High** based on:
# - `sqft_living` — area of the house
# - `bedrooms` — number of rooms
#
# Label is created by splitting on the **median price**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %% [markdown]
# ## 1. Load Dataset

# %%
df = pd.read_csv('house_prices.csv') 
print('Shape:', df.shape)
df[['sqft_living', 'bedrooms', 'price']].describe()
# Out:
# Shape: (21613, 21)
#         sqft_living      bedrooms         price
# count  21613.000000  21613.000000  2.161300e+04
# mean    2079.899736      3.370842  5.400881e+05
# std      918.440897      0.930062  3.671272e+05
# min      290.000000      0.000000  7.500000e+04
# 25%     1427.000000      3.000000  3.219500e+05
# 50%     1910.000000      3.000000  4.500000e+05
# 75%     2550.000000      4.000000  6.450000e+05
# max    13540.000000     33.000000  7.700000e+06

# %% [markdown]
# ## 2. Create Binary Label (Median Split)

# %%
median_price = df['price'].median()
df['price_category'] = (df['price'] >= median_price).astype(int)

print(f'Median Price : ${median_price:,.0f}')
print(f'Low  (0)     : {(df["price_category"]==0).sum()} samples')
print(f'High (1)     : {(df["price_category"]==1).sum()} samples')

df['price_category'].value_counts().plot(kind='bar', color=['#3b82f6','#f97316'],
                                          edgecolor='black', figsize=(5,3))
plt.title('Class Distribution')
plt.xticks([0,1], ['Low','High'], rotation=0)
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# Median Price : $450,000
# Low  (0)     : 10692 samples
# High (1)     : 10921 samples

# %% [markdown]
# ## 3. Prepare Features & Split

# %%
X = df[['sqft_living', 'bedrooms']].values
y = df['price_category'].values

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)
print(f'Train: {len(X_train)}  |  Test: {len(X_test)}')
# Out:
# Train: 17290  |  Test: 4323

# %% [markdown]
# ## 4. Build Neural Network

# %%
model = keras.Sequential([
    layers.Input(shape=(2,)),           # sqft_living, bedrooms
    layers.Dense(16, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1,  activation='sigmoid'),
], name='house_price_classifier')

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "house_price_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 337 (1.32 KB)
#  Trainable params: 337 (1.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 5. Train

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6909 - loss: 0.6211 - val_accuracy: 0.7102 - val_loss: 0.5606
# Epoch 2/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7244 - loss: 0.5391 - val_accuracy: 0.7091 - val_loss: 0.5571
# Epoch 3/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7256 - loss: 0.5343 - val_accuracy: 0.7114 - val_loss: 0.5470
# Epoch 4/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7268 - loss: 0.5331 - val_accuracy: 0.7114 - val_loss: 0.5467
# Epoch 5/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7262 - loss: 0.5324 - val_accuracy: 0.7154 - val_loss: 0.5475
# Epoch 6/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7263 - loss: 0.5318 - val_accuracy: 0.7097 - val_loss: 0.5491
# Epoch 7/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7264 - loss: 0.5325 - val_accuracy: 0.7131 - val_loss: 0.5452
# Epoch 8/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7272 - loss: 0.5316 - val_accuracy: 0.7137 - val_loss: 0.5474
# Epoch 9/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7261 - loss: 0.5312 - val_accuracy: 0.7091 - val_loss: 0.5476
# Epoch 10/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7273 - loss: 0.5314 - val_accuracy: 0.7137 - val_loss: 0.5484
# Epoch 11/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7266 - loss: 0.5316 - val_accuracy: 0.7143 - val_loss: 0.5486
# Epoch 12/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7274 - loss: 0.5315 - val_accuracy: 0.7149 - val_loss: 0.5464
# Epoch 13/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7278 - loss: 0.5319 - val_accuracy: 0.7108 - val_loss: 0.5447
# Epoch 14/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7265 - loss: 0.5313 - val_accuracy: 0.7126 - val_loss: 0.5445
# Epoch 15/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7276 - loss: 0.5310 - val_accuracy: 0.7108 - val_loss: 0.5451
# Epoch 16/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7281 - loss: 0.5314 - val_accuracy: 0.7166 - val_loss: 0.5451
# Epoch 17/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7273 - loss: 0.5313 - val_accuracy: 0.7097 - val_loss: 0.5445
# Epoch 18/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7260 - loss: 0.5310 - val_accuracy: 0.7154 - val_loss: 0.5485
# Epoch 19/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7271 - loss: 0.5308 - val_accuracy: 0.7068 - val_loss: 0.5619
# Epoch 20/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7278 - loss: 0.5315 - val_accuracy: 0.7143 - val_loss: 0.5443
# Epoch 21/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7258 - loss: 0.5314 - val_accuracy: 0.7166 - val_loss: 0.5446
# Epoch 22/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7270 - loss: 0.5310 - val_accuracy: 0.7114 - val_loss: 0.5443
# Epoch 23/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7265 - loss: 0.5314 - val_accuracy: 0.7131 - val_loss: 0.5444
# Epoch 24/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7255 - loss: 0.5310 - val_accuracy: 0.7114 - val_loss: 0.5443
# Epoch 25/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7269 - loss: 0.5313 - val_accuracy: 0.7160 - val_loss: 0.5463
# Epoch 26/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7266 - loss: 0.5309 - val_accuracy: 0.7097 - val_loss: 0.5446
# Epoch 27/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7276 - loss: 0.5321 - val_accuracy: 0.7160 - val_loss: 0.5454
# Epoch 28/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7281 - loss: 0.5306 - val_accuracy: 0.7195 - val_loss: 0.5464
# Epoch 29/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7270 - loss: 0.5307 - val_accuracy: 0.7097 - val_loss: 0.5442
# Epoch 30/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7266 - loss: 0.5311 - val_accuracy: 0.7091 - val_loss: 0.5444
# Epoch 31/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7252 - loss: 0.5314 - val_accuracy: 0.7137 - val_loss: 0.5444
# Epoch 32/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7275 - loss: 0.5313 - val_accuracy: 0.7137 - val_loss: 0.5443
# Epoch 33/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7273 - loss: 0.5308 - val_accuracy: 0.7137 - val_loss: 0.5449
# Epoch 34/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7265 - loss: 0.5309 - val_accuracy: 0.7114 - val_loss: 0.5442
# Epoch 35/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7271 - loss: 0.5310 - val_accuracy: 0.7126 - val_loss: 0.5439
# Epoch 36/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7291 - loss: 0.5303 - val_accuracy: 0.7091 - val_loss: 0.5441
# Epoch 37/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7247 - loss: 0.5311 - val_accuracy: 0.7131 - val_loss: 0.5500
# Epoch 38/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7266 - loss: 0.5308 - val_accuracy: 0.7091 - val_loss: 0.5445
# Epoch 39/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7251 - loss: 0.5304 - val_accuracy: 0.7166 - val_loss: 0.5457
# Epoch 40/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7261 - loss: 0.5308 - val_accuracy: 0.7126 - val_loss: 0.5503
# Epoch 41/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7257 - loss: 0.5305 - val_accuracy: 0.7201 - val_loss: 0.5469
# Epoch 42/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7274 - loss: 0.5303 - val_accuracy: 0.7178 - val_loss: 0.5461
# Epoch 43/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7278 - loss: 0.5307 - val_accuracy: 0.7166 - val_loss: 0.5451
# Epoch 44/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7267 - loss: 0.5304 - val_accuracy: 0.7108 - val_loss: 0.5486
# Epoch 45/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7262 - loss: 0.5312 - val_accuracy: 0.7102 - val_loss: 0.5436
# Epoch 46/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7284 - loss: 0.5299 - val_accuracy: 0.7172 - val_loss: 0.5450
# Epoch 47/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7269 - loss: 0.5302 - val_accuracy: 0.7102 - val_loss: 0.5435
# Epoch 48/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7252 - loss: 0.5305 - val_accuracy: 0.7091 - val_loss: 0.5444
# Epoch 49/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7262 - loss: 0.5307 - val_accuracy: 0.7137 - val_loss: 0.5445
# Epoch 50/50
# 487/487 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7275 - loss: 0.5301 - val_accuracy: 0.7108 - val_loss: 0.5438

# %% [markdown]
# ## 6. Evaluate

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
y_pred_prob = model.predict(X_test, verbose=0).flatten()
y_pred = (y_pred_prob >= 0.5).astype(int)

print(f'Test Accuracy : {acc*100:.2f}%')
print(f'Test Loss     : {loss:.4f}')
print()
print(classification_report(y_test, y_pred, target_names=['Low','High']))
# Out:
# Test Accuracy : 72.50%
# Test Loss     : 0.5289
#
#               precision    recall  f1-score   support
#
#          Low       0.70      0.77      0.74      2139
#         High       0.75      0.68      0.71      2184
#
#     accuracy                           0.72      4323
#    macro avg       0.73      0.73      0.72      4323
# weighted avg       0.73      0.72      0.72      4323

# %% [markdown]
# ## 7. Plots — Training Curve & Confusion Matrix

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# Training curve
ax = axes[0]
ax.plot(history.history['accuracy'],     label='Train Accuracy', color='#f97316', lw=2)
ax.plot(history.history['val_accuracy'], label='Val Accuracy',   color='#f97316', lw=2, ls='--')
ax.plot(history.history['loss'],         label='Train Loss',     color='#94a3b8', lw=1.5)
ax.set_title('Task 3 — Training Curve (ReLU)', fontsize=12)
ax.set_xlabel('Epoch'); ax.set_ylabel('Value')
ax.legend(); ax.grid(alpha=0.3)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Low','High'])
disp.plot(ax=axes[1], colorbar=False, cmap='YlOrRd')
axes[1].set_title('Task 3 — Confusion Matrix', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Sample Predictions

# %%
X_test_orig = scaler.inverse_transform(X_test)
results_df = pd.DataFrame({
    'sqft_living': X_test_orig[:, 0].astype(int),
    'bedrooms':    X_test_orig[:, 1].astype(int),
    'Actual':      ['High' if v else 'Low' for v in y_test],
    'Predicted':   ['High' if v else 'Low' for v in y_pred],
    'Probability': y_pred_prob.round(3),
    'Correct':     ['✓' if a==p else '✗' for a,p in zip(y_test, y_pred)],
})
results_df.head(12)
# Out:
#     sqft_living  bedrooms Actual Predicted  Probability Correct
# 0          1610         3   High       Low        0.344       ✗
# 1           880         2    Low       Low        0.147       ✓
# 2          1070         3    Low       Low        0.148       ✓
# 3          2800         5   High      High        0.735       ✓
# 4          2490         4   High      High        0.683       ✓
# 5          2690         4    Low      High        0.764       ✗
# 6          3370         3   High      High        0.950       ✓
# 7          1360         3    Low       Low        0.239       ✓
# 8          1760         3    Low       Low        0.416       ✓
# 9          4340         3   High      High        0.989       ✓
# 10         3238         4    Low      High        0.908       ✗
# 11         1600         3   High       Low        0.339       ✗
