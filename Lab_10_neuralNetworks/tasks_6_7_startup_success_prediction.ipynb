# %% [markdown]
# # Neural Networks — Tasks 6 & 7
# ### Computer Vision with TensorFlow & Keras
# ---
# - **Task 6:** Predict startup success (0/1) based on `Funding_Amount` and `Employees_Count`
# - **Task 7:** Expand layers/neurons and analyse overfitting / underfitting

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %% [markdown]
# ---
# # Task 6 — Startup Success Prediction
# **Goal:** Binary classification — will a startup succeed?
# **Features:** `Funding_Amount`, `Employees_Count` (team size)
# **Target:** `Startup_Status` (0 = Failed, 1 = Success)

# %% [markdown]
# ### 6.1 Load & Explore Dataset

# %%
df = pd.read_csv('startup_data.csv')   

print('Dataset shape:', df.shape)
print('\nClass balance:')
print(df['Startup_Status'].value_counts())
df.head()
# Out:
# Dataset shape: (5000, 15)
#
# Class balance:
# Startup_Status
# 1    5000
# Name: count, dtype: int64
#   Startup_Name    Industry  Startup_Age  Funding_Amount  Number_of_Founders  \
# 0    Startup_1   Logistics            8        18328419                   2
# 1    Startup_2   Education            3        39753708                   3
# 2    Startup_3  Healthcare           14        18073294                   1
# 3    Startup_4  E-commerce            5        19435653                   4
# 4    Startup_5     Finance           14         4205797                   4
#
#    Founder_Experience  Employees_Count   Revenue  Burn_Rate Market_Size  \
# 0                  13              581  97866143     602731      Medium
# 1                  16              529  36868744     820698       Large
# 2                  28               82   3478737     992205       Small
# 3                  14              234  80716899     536747      Medium
# 4                  17              960  53347246     555199      Medium
#
#   Business_Model  Product_Uniqueness_Score  Customer_Retention_Rate  \
# 0            B2B                         2                    79.61
# 1            B2C                         3                    32.47
# 2            B2C                         1                     9.88
# 3            B2C                         9                    23.20
# 4         Hybrid                         3                    73.52
#
#    Marketing_Expense  Startup_Status
# 0             987830               1
# 1             599615               1
# 2             780730               1
# 3             188588               1
# 4             310892               1

# %%
df[['Funding_Amount', 'Employees_Count', 'Startup_Status']].describe()

# %% [markdown]
# ### 6.2 Prepare Features & Normalize

# %%
X = df[['Funding_Amount', 'Employees_Count']].values
y = df['Startup_Status'].values

scaler_6 = MinMaxScaler()
X_scaled = scaler_6.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print(f'Train samples : {len(X_train)}')
print(f'Test  samples : {len(X_test)}')
# Out:
# Train samples : 4000
# Test  samples : 1000

# %% [markdown]
# ### 6.3 Build Neural Network

# %%
model_6 = keras.Sequential([
    layers.Input(shape=(2,)),            # Funding_Amount, Employees_Count
    layers.Dense(16, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1,  activation='sigmoid'),  # binary output
], name='task6_startup')

model_6.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model_6.summary()
# Out:
# Model: "task6_startup"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 337 (1.32 KB)
#  Trainable params: 337 (1.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 6.4 Train

# %%
history_6 = model_6.fit(
    X_train, y_train,
    epochs=80,
    batch_size=32,
    validation_split=0.15,
    verbose=1
)
# Out:
# Epoch 1/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9929 - loss: 0.3930 - val_accuracy: 1.0000 - val_loss: 0.1755
# Epoch 2/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0913 - val_accuracy: 1.0000 - val_loss: 0.0421
# Epoch 3/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 4/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 5/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 6/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 7/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 8/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 9/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 10/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 11/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 9.2391e-04
# Epoch 12/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 8.1819e-04 - val_accuracy: 1.0000 - val_loss: 7.6396e-04
# Epoch 13/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.8023e-04 - val_accuracy: 1.0000 - val_loss: 6.4057e-04
# Epoch 14/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 5.7241e-04 - val_accuracy: 1.0000 - val_loss: 5.4421e-04
# Epoch 15/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 4.8754e-04 - val_accuracy: 1.0000 - val_loss: 4.6596e-04
# Epoch 16/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 4.1886e-04 - val_accuracy: 1.0000 - val_loss: 4.0255e-04
# Epoch 17/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.6224e-04 - val_accuracy: 1.0000 - val_loss: 3.5067e-04
# Epoch 18/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 3.1572e-04 - val_accuracy: 1.0000 - val_loss: 3.0729e-04
# Epoch 19/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.7742e-04 - val_accuracy: 1.0000 - val_loss: 2.7096e-04
# Epoch 20/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.4468e-04 - val_accuracy: 1.0000 - val_loss: 2.4007e-04
# Epoch 21/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.1718e-04 - val_accuracy: 1.0000 - val_loss: 2.1377e-04
# Epoch 22/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.9362e-04 - val_accuracy: 1.0000 - val_loss: 1.9128e-04
# Epoch 23/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.7337e-04 - val_accuracy: 1.0000 - val_loss: 1.7211e-04
# Epoch 24/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.5581e-04 - val_accuracy: 1.0000 - val_loss: 1.5496e-04
# Epoch 25/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.4044e-04 - val_accuracy: 1.0000 - val_loss: 1.3993e-04
# Epoch 26/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.2692e-04 - val_accuracy: 1.0000 - val_loss: 1.2687e-04
# Epoch 27/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.1504e-04 - val_accuracy: 1.0000 - val_loss: 1.1514e-04
# Epoch 28/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0450e-04 - val_accuracy: 1.0000 - val_loss: 1.0507e-04
# Epoch 29/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 9.5170e-05 - val_accuracy: 1.0000 - val_loss: 9.5914e-05
# Epoch 30/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 8.6845e-05 - val_accuracy: 1.0000 - val_loss: 8.7684e-05
# Epoch 31/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.9388e-05 - val_accuracy: 1.0000 - val_loss: 8.0308e-05
# Epoch 32/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.2700e-05 - val_accuracy: 1.0000 - val_loss: 7.3674e-05
# Epoch 33/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.6632e-05 - val_accuracy: 1.0000 - val_loss: 6.7560e-05
# Epoch 34/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.1209e-05 - val_accuracy: 1.0000 - val_loss: 6.2222e-05
# Epoch 35/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 5.6312e-05 - val_accuracy: 1.0000 - val_loss: 5.7377e-05
# Epoch 36/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 5.1870e-05 - val_accuracy: 1.0000 - val_loss: 5.2947e-05
# Epoch 37/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 4.7844e-05 - val_accuracy: 1.0000 - val_loss: 4.8862e-05
# Epoch 38/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 4.4180e-05 - val_accuracy: 1.0000 - val_loss: 4.5151e-05
# Epoch 39/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 4.0832e-05 - val_accuracy: 1.0000 - val_loss: 4.1810e-05
# Epoch 40/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.7786e-05 - val_accuracy: 1.0000 - val_loss: 3.8747e-05
# Epoch 41/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.4998e-05 - val_accuracy: 1.0000 - val_loss: 3.5954e-05
# Epoch 42/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.2441e-05 - val_accuracy: 1.0000 - val_loss: 3.3393e-05
# Epoch 43/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.0088e-05 - val_accuracy: 1.0000 - val_loss: 3.1027e-05
# Epoch 44/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.7925e-05 - val_accuracy: 1.0000 - val_loss: 2.8839e-05
# Epoch 45/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.5897e-05 - val_accuracy: 1.0000 - val_loss: 2.6738e-05
# Epoch 46/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.4054e-05 - val_accuracy: 1.0000 - val_loss: 2.4888e-05
# Epoch 47/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.2373e-05 - val_accuracy: 1.0000 - val_loss: 2.3154e-05
# Epoch 48/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.0818e-05 - val_accuracy: 1.0000 - val_loss: 2.1588e-05
# Epoch 49/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.9391e-05 - val_accuracy: 1.0000 - val_loss: 2.0129e-05
# Epoch 50/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.8069e-05 - val_accuracy: 1.0000 - val_loss: 1.8772e-05
# Epoch 51/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.6836e-05 - val_accuracy: 1.0000 - val_loss: 1.7537e-05
# Epoch 52/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.5699e-05 - val_accuracy: 1.0000 - val_loss: 1.6339e-05
# Epoch 53/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.4645e-05 - val_accuracy: 1.0000 - val_loss: 1.5276e-05
# Epoch 54/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.3676e-05 - val_accuracy: 1.0000 - val_loss: 1.4261e-05
# Epoch 55/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.2771e-05 - val_accuracy: 1.0000 - val_loss: 1.3346e-05
# Epoch 56/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 1.1934e-05 - val_accuracy: 1.0000 - val_loss: 1.2483e-05
# Epoch 57/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.1153e-05 - val_accuracy: 1.0000 - val_loss: 1.1677e-05
# Epoch 58/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0413e-05 - val_accuracy: 1.0000 - val_loss: 1.0903e-05
# Epoch 59/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 9.7352e-06 - val_accuracy: 1.0000 - val_loss: 1.0211e-05
# Epoch 60/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 9.1088e-06 - val_accuracy: 1.0000 - val_loss: 9.5646e-06
# Epoch 61/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 8.5232e-06 - val_accuracy: 1.0000 - val_loss: 8.9562e-06
# Epoch 62/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.9787e-06 - val_accuracy: 1.0000 - val_loss: 8.3897e-06
# Epoch 63/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.4709e-06 - val_accuracy: 1.0000 - val_loss: 7.8685e-06
# Epoch 64/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.9976e-06 - val_accuracy: 1.0000 - val_loss: 7.3684e-06
# Epoch 65/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.5540e-06 - val_accuracy: 1.0000 - val_loss: 6.9098e-06
# Epoch 66/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.1418e-06 - val_accuracy: 1.0000 - val_loss: 6.4762e-06
# Epoch 67/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 5.7549e-06 - val_accuracy: 1.0000 - val_loss: 6.0790e-06
# Epoch 68/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 5.3938e-06 - val_accuracy: 1.0000 - val_loss: 5.7065e-06
# Epoch 69/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 5.0592e-06 - val_accuracy: 1.0000 - val_loss: 5.3454e-06
# Epoch 70/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 4.7420e-06 - val_accuracy: 1.0000 - val_loss: 5.0290e-06
# Epoch 71/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 4.4499e-06 - val_accuracy: 1.0000 - val_loss: 4.7116e-06
# Epoch 72/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 4.1739e-06 - val_accuracy: 1.0000 - val_loss: 4.4233e-06
# Epoch 73/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.9145e-06 - val_accuracy: 1.0000 - val_loss: 4.1552e-06
# Epoch 74/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.6688e-06 - val_accuracy: 1.0000 - val_loss: 3.8914e-06
# Epoch 75/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.4404e-06 - val_accuracy: 1.0000 - val_loss: 3.6566e-06
# Epoch 76/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.2299e-06 - val_accuracy: 1.0000 - val_loss: 3.4383e-06
# Epoch 77/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.0324e-06 - val_accuracy: 1.0000 - val_loss: 3.2283e-06
# Epoch 78/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.8475e-06 - val_accuracy: 1.0000 - val_loss: 3.0347e-06
# Epoch 79/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.6750e-06 - val_accuracy: 1.0000 - val_loss: 2.8486e-06
# Epoch 80/80
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.5122e-06 - val_accuracy: 1.0000 - val_loss: 2.6804e-06

# %% [markdown]
# ### 6.5 Evaluate

# %%
loss_6, acc_6 = model_6.evaluate(X_test, y_test, verbose=0)
y_pred_prob_6 = model_6.predict(X_test, verbose=0).flatten()
y_pred_6      = (y_pred_prob_6 >= 0.5).astype(int)

print(f'Test Accuracy : {acc_6*100:.2f}%')
print(f'Test Loss     : {loss_6:.4f}')
print()
print(classification_report(
    y_test,
    y_pred_6,
    labels=[0, 1],
    target_names=['Failed', 'Success']
))
# print(classification_report(y_test, y_pred_6, target_names=['Failed', 'Success']))
# Out:
# Test Accuracy : 100.00%
# Test Loss     : 0.0000
#
#               precision    recall  f1-score   support
#
#       Failed       0.00      0.00      0.00         0
#      Success       1.00      1.00      1.00      1000
#
#     accuracy                           1.00      1000
#    macro avg       0.50      0.50      0.50      1000
# weighted avg       1.00      1.00      1.00      1000

# %%
# Sample predictions
X_orig = scaler_6.inverse_transform(X_test)
labels = {0: 'Failed', 1: 'Success'}

print(f'{"Funding":>14}  {"Team":>6}  {"Actual":>8}  {"Pred":>8}  {"Prob":>8}')
print('-' * 52)
for i in range(min(8, len(X_test))):
    print(f'{X_orig[i][0]:>14,.0f}  {X_orig[i][1]:>6.0f}  '
          f'{labels[y_test[i]]:>8}  {labels[y_pred_6[i]]:>8}  {y_pred_prob_6[i]:>8.3f}')
# Out:
#        Funding    Team    Actual      Pred      Prob
# ----------------------------------------------------
#     49,207,779     212   Success   Success     1.000
#     35,717,984     365   Success   Success     1.000
#     41,540,249     696   Success   Success     1.000
#     28,270,904     802   Success   Success     1.000
#     35,033,390     311   Success   Success     1.000
#      7,214,948     405   Success   Success     1.000
#     30,233,375     610   Success   Success     1.000
#     21,765,814     805   Success   Success     1.000

# %% [markdown]
# ### 6.6 Plot — Training Curve & Confusion Matrix

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
EP6 = range(1, 81)

# Training curve
ax = axes[0]
ax.plot(EP6, history_6.history['accuracy'],     color='#f97316', lw=2.5, label='Train Accuracy')
ax.plot(EP6, history_6.history['val_accuracy'], color='#f97316', lw=2,   ls='--', label='Val Accuracy')
ax.plot(EP6, history_6.history['loss'],         color='#94a3b8', lw=1.5, label='Train Loss')
ax.set_title('Task 6 — Training Curve', fontsize=13)
ax.set_xlabel('Epoch'); ax.set_ylabel('Value')
ax.legend(); ax.grid(alpha=0.3)

# Confusion matrix
ax = axes[1]

cm = confusion_matrix(y_test, y_pred_6, labels=[0, 1])  # ✅ FIX

im = ax.imshow(cm, cmap='Oranges')

for i in range(2):
    for j in range(2):
        ax.text(j, i, str(cm[i,j]), ha='center', va='center',
                fontsize=18, fontweight='bold')

ax.set_xticks([0,1]); ax.set_yticks([0,1])
ax.set_xticklabels(['Failed','Success'])
ax.set_yticklabels(['Failed','Success'])
ax.set_xlabel('Predicted'); ax.set_ylabel('Actual')
ax.set_title('Task 6 — Confusion Matrix', fontsize=13)

plt.colorbar(im, ax=ax)

plt.tight_layout()
plt.savefig('task6_results.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# # Task 7 — Add More Layers & Neurons: Overfitting / Underfitting Analysis
#
# Three model sizes are trained on the **same** dataset:
#
# | Model | Layers & Neurons | Risk |
# |---|---|---|
# | **Small** | 4 → 4 → 1 | Underfitting |
# | **Medium** | 16 → 16 → 1 | Baseline |
# | **Large** | 128 → 128 → 64 → 64 → 32 → 1 | Overfitting |

# %% [markdown]
# ### 7.1 Define Model Configurations

# %%
EPOCHS_7 = 150

model_configs = {
    'Small (underfit risk)': [
        layers.Dense(4,  activation='relu'),
        layers.Dense(4,  activation='relu'),
        layers.Dense(1,  activation='sigmoid'),
    ],
    'Medium (baseline)': [
        layers.Dense(16, activation='relu'),
        layers.Dense(16, activation='relu'),
        layers.Dense(1,  activation='sigmoid'),
    ],
    'Large (overfit risk)': [
        layers.Dense(128, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(64,  activation='relu'),
        layers.Dense(64,  activation='relu'),
        layers.Dense(32,  activation='relu'),
        layers.Dense(1,   activation='sigmoid'),
    ],
}

print('Model configurations defined.')
for name, lyrs in model_configs.items():
    print(f'  {name}: {len(lyrs)} layers (excl. input)')
# Out:
# Model configurations defined.
#   Small (underfit risk): 3 layers (excl. input)
#   Medium (baseline): 3 layers (excl. input)
#   Large (overfit risk): 6 layers (excl. input)

# %% [markdown]
# ### 7.2 Train All Three Models

# %%
histories_7  = {}
test_results = {}

for name, layer_list in model_configs.items():
    print(f'\nTraining: {name} ...')
    m = keras.Sequential(
        [layers.Input(shape=(2,))] + layer_list,
        name=name.split()[0].lower()
    )
    m.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    h = m.fit(
        X_train, y_train,
        epochs=EPOCHS_7,
        batch_size=32,
        validation_split=0.15,
        verbose=0
    )
    loss, acc = m.evaluate(X_test, y_test, verbose=0)
    train_acc = h.history['accuracy'][-1]
    val_acc   = h.history['val_accuracy'][-1]
    gap       = train_acc - val_acc

    histories_7[name]  = h
    test_results[name] = {
        'test_acc':  acc,
        'test_loss': loss,
        'train_acc': train_acc,
        'val_acc':   val_acc,
        'gap':       gap,
        'params':    m.count_params(),
    }

    diag = ('⚠  OVERFITTING'  if gap > 0.08
            else '⚠  UNDERFITTING' if val_acc < 0.65
            else '✓  GOOD FIT')

    print(f'  Params    : {m.count_params():,}')
    print(f'  Train acc : {train_acc*100:.2f}%')
    print(f'  Val   acc : {val_acc*100:.2f}%')
    print(f'  Test  acc : {acc*100:.2f}%')
    print(f'  Gap       : {gap*100:.2f}%  →  {diag}')
# Out:
# Training: Small (underfit risk) ...
#   Params    : 37
#   Train acc : 100.00%
#   Val   acc : 100.00%
#   Test  acc : 100.00%
#   Gap       : 0.00%  →  ✓  GOOD FIT
#
# Training: Medium (baseline) ...
#   Params    : 337
#   Train acc : 100.00%
#   Val   acc : 100.00%
#   Test  acc : 100.00%
#   Gap       : 0.00%  →  ✓  GOOD FIT
#
# Training: Large (overfit risk) ...
#   Params    : 31,425
#   Train acc : 100.00%
#   Val   acc : 100.00%
#   Test  acc : 100.00%
#   Gap       : 0.00%  →  ✓  GOOD FIT

# %% [markdown]
# ### 7.3 Overfitting / Underfitting Summary Table

# %%
rows = []
for name, r in test_results.items():
    gap  = r['gap']
    diag = 'OVERFIT'  if gap > 0.08 else ('UNDERFIT' if r['val_acc'] < 0.65 else 'GOOD FIT')
    rows.append({
        'Model':     name,
        'Params':    r['params'],
        'Train Acc': f"{r['train_acc']*100:.1f}%",
        'Val Acc':   f"{r['val_acc']*100:.1f}%",
        'Test Acc':  f"{r['test_acc']*100:.1f}%",
        'Gap':       f"{gap*100:.1f}%",
        'Diagnosis': diag,
    })

summary_df = pd.DataFrame(rows).set_index('Model')
summary_df
# Out:
#                        Params Train Acc Val Acc Test Acc   Gap Diagnosis
# Model
# Small (underfit risk)      37    100.0%  100.0%   100.0%  0.0%  GOOD FIT
# Medium (baseline)         337    100.0%  100.0%   100.0%  0.0%  GOOD FIT
# Large (overfit risk)    31425    100.0%  100.0%   100.0%  0.0%  GOOD FIT

# %% [markdown]
# ### 7.4 Plot — Training Accuracy Curves (All 3 Models)

# %%
COLORS = {
    'Small (underfit risk)': '#3b82f6',
    'Medium (baseline)':     '#f97316',
    'Large (overfit risk)':  '#ef4444',
}
EP7 = range(1, EPOCHS_7 + 1)

fig, ax = plt.subplots(figsize=(14, 5))
for name, h in histories_7.items():
    c = COLORS[name]
    ax.plot(EP7, h.history['accuracy'],     color=c, lw=2.5, label=f'{name} — train')
    ax.plot(EP7, h.history['val_accuracy'], color=c, lw=1.5, ls='--', alpha=0.6, label=f'{name} — val')

ax.set_title('Task 7 — Training vs Validation Accuracy: Small / Medium / Large', fontsize=13)
ax.set_xlabel('Epoch'); ax.set_ylabel('Accuracy')
ax.legend(ncol=3, fontsize=9); ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('task7_accuracy.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 7.5 Plot — Loss Curves (Overfitting vs Underfitting)

# %%
fig, ax = plt.subplots(figsize=(14, 5))

for name in ['Large (overfit risk)', 'Small (underfit risk)']:
    c = COLORS[name]
    h = histories_7[name]
    ax.plot(EP7, h.history['loss'],     color=c, lw=2.5, label=f'{name} — train loss')
    ax.plot(EP7, h.history['val_loss'], color=c, lw=2,   ls='--', label=f'{name} — val loss')

ax.set_title('Task 7 — Loss Curves: Overfitting (Large) vs Underfitting (Small)', fontsize=13)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.legend(); ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('task7_loss.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 7.6 Plot — Final Accuracy Bar Chart (Train / Val / Test)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
names  = list(test_results.keys())
x      = np.arange(len(names))
t_acc  = [test_results[n]['train_acc'] * 100 for n in names]
v_acc  = [test_results[n]['val_acc']   * 100 for n in names]
s_acc  = [test_results[n]['test_acc']  * 100 for n in names]
w = 0.25

b1 = ax.bar(x - w, t_acc, w, label='Train', color='#f97316')
b2 = ax.bar(x,     v_acc, w, label='Val',   color='#8b5cf6')
b3 = ax.bar(x + w, s_acc, w, label='Test',  color='#22c55e')

for bars in [b1, b2, b3]:
    for bar in bars:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.3,
                f'{bar.get_height():.1f}%', ha='center', va='bottom', fontsize=9)

ax.set_xticks(x)
ax.set_xticklabels(['Small', 'Medium', 'Large'])
ax.set_ylim(0, 115)
ax.set_ylabel('Accuracy (%)')
ax.set_title('Task 7 — Fit Analysis: Train vs Val vs Test Accuracy', fontsize=13)
ax.legend(); ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig('task7_bar.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## Summary
#
# | Task | Description | Key Result |
# |---|---|---|
# | **6** | Startup success (Funding + Team Size) | Binary classifier with sigmoid output |
# | **7 Small** | 4 → 4 → 1 (18 params) | Risk of **underfitting** — model too simple |
# | **7 Medium** | 16 → 16 → 1 (305 params) | **Baseline** — balanced train/val gap |
# | **7 Large** | 128→128→64→64→32→1 (43k params) | Risk of **overfitting** — train >> val |
#
# **Overfitting** is detected when `train_acc >> val_acc` (gap > 8%).
# **Underfitting** is detected when both `train_acc` and `val_acc` remain low (< 65%).
# **Remedies:** Dropout, L2 regularisation, early stopping, or more data.
